# %%
database = {
    "log": [
        {"logfile": "log_001", "vehicle": "vehicle_01", "date_captured": "2025-04-20", "location": "Berlin"},
        {"logfile": "log_002", "vehicle": "vehicle_01", "date_captured": "2025-04-21", "location": "Munich"},
        {"logfile": "log_003", "vehicle": "vehicle_01", "date_captured": "2025-04-22", "location": "Frunkfurt"}
    ],
    "sample": [
        {"timestamp": 1650001234567, "log_token": "log_001", "key_camera_token": "cam_front"},
        {"timestamp": 1650001234568, "log_token": "log_002", "key_camera_token": "cam_front"},
        {"timestamp": 1650001234569, "log_token": "log_003", "key_camera_token": "cam_front"}
    ],
    "sample_data": [
        {
            "sample_token": "sample_001",
            "ego_pose_token": "pose_001",
            "calibrated_sensor_token": "calib_001",
            "filename": "image_001.jpg",
            "fileformat": "jpg",
            "width": 1920,
            "height": 1080,
            "timestamp": 1650001234567,
            "is_key_frame": True,
            "next": "sample_002",
            "prev": None
        },
        {
            "sample_token": "sample_002",
            "ego_pose_token": "pose_001",
            "calibrated_sensor_token": "calib_001",
            "filename": "image_001.jpg",
            "fileformat": "jpg",
            "width": 1920,
            "height": 1080,
            "timestamp": 1650001234567,
            "is_key_frame": True,
            "next": "sample_002",
            "prev": None
        },
        {
            "sample_token": "sample_003",
            "ego_pose_token": "pose_001",
            "calibrated_sensor_token": "calib_001",
            "filename": "image_001.jpg",
            "fileformat": "jpg",
            "width": 1920,
            "height": 1080,
            "timestamp": 1650001234567,
            "is_key_frame": True,
            "next": "sample_002",
            "prev": None
        }
    ],
    "ego_pose": [
        {
            "translation": [10.5, 5.2, 0.3],
            "rotation": [0.0, 0.0, 0.0, 1.0],
            "timestamp": 1650001234567,
            "rotation_rate": [0.01, 0.0, 0.0],
            "acceleration": [0.1, 0.0, -9.8],
            "speed": 12.3
        },
        {
            "translation": [11.5, 5.2, 0.3],
            "rotation": [0.0, 0.0, 0.0, 1.0],
            "timestamp": 1650001234567,
            "rotation_rate": [0.01, 0.0, 0.0],
            "acceleration": [0.1, 0.0, -9.8],
            "speed": 12.4
        },
        {
            "translation": [15.5, 5.2, 0.3],
            "rotation": [0.0, 0.0, 0.0, 1.0],
            "timestamp": 1650001234567,
            "rotation_rate": [0.01, 0.0, 0.0],
            "acceleration": [0.1, 0.0, -9.8],
            "speed": 12.6
        }
    ],
    "calibrated_sensor": [
        {
            "sensor_token": "sensor_001",
            "translation": [1.5, 0.0, 1.2],
            "rotation": [0.0, 0.0, 0.0, 1.0],
            "camera_intrinsic": [[1000, 0, 960], [0, 1000, 540], [0, 0, 1]],
            "camera_distortion": [0.1, -0.1, 0.0, 0.0, 0.01]
        },
       { "sensor_token": "sensor_002",
            "translation": [1.5, 0.0, 1.2],
            "rotation": [0.0, 0.0, 0.0, 1.0],
            "camera_intrinsic": [[1000, 0, 960], [0, 1000, 540], [0, 0, 1]],
            "camera_distortion": [0.1, -0.1, 0.0, 0.0, 0.01]
        },
       { "sensor_token": "sensor_003",
            "translation": [1.5, 0.0, 1.2],
            "rotation": [0.0, 0.0, 0.0, 1.0],
            "camera_intrinsic": [[1000, 0, 960], [0, 1000, 540], [0, 0, 1]],
            "camera_distortion": [0.1, -0.1, 0.0, 0.0, 0.01]
        },
       { "sensor_token": "sensor_004",
            "translation": [1.5, 0.0, 1.2],
            "rotation": [0.0, 0.0, 0.0, 1.0],
            "camera_intrinsic": [[1000, 0, 960], [0, 1000, 540], [0, 0, 1]],
            "camera_distortion": [0.1, -0.1, 0.0, 0.0, 0.01]
        }


    ],
    "sensor": [
        {"channel": "CAM_FRONT", "modality": "camera"},
        {"channel": "CAM_Back", "modality": "camera"},
        {"channel": "CAM_Right", "modality": "camera"},
        {"channel": "CAM_Left", "modality": "camera"}
    ],
    "surface_ann": [
        {"sample_data_token": "sample_001", "category_token": "road", "mask": "mask_001.png"},
        {"sample_data_token": "sample_002", "category_token": "car", "mask": "mask_002.png"},
        {"sample_data_token": "sample_003", "category_token": "road", "mask": "mask_003.png"},
    ],
    "object_ann": [
        {
            "sample_data_token": "sample_001",
            "category_token": "road",
            "attribute_tokens": "red",
            "bbox": [100, 200, 150, 250],
            "mask": "mask_001.png"
        },
        {
            "sample_data_token": "sample_002",
            "category_token": "car",
            "attribute_tokens": ["moving", "red"],
            "bbox": [100, 200, 150, 250],
            "mask": "mask_002.png"
        },
        {
            "sample_data_token": "sample_003",
            "category_token": "road",
            "attribute_tokens": "red",
            "bbox": [100, 200, 150, 250],
            "mask": "mask_003.png"
        },
    ],
    "category": [
        {"name": "car", "description": "Motor vehicle with four wheels"},
        {"name": "road", "description": "Surface for vehicles"},
    ],
    "attribute": [
        {"name": "moving", "description": "Object is in motion"},
        {"name": "red", "description": "Object is red-colored"},
    ],
}

# %%
print(database)
# Out:
# {'log': [{'logfile': 'log_001', 'vehicle': 'vehicle_01', 'date_captured': '2025-04-20', 'location': 'Berlin'}, {'logfile': 'log_002', 'vehicle': 'vehicle_01', 'date_captured': '2025-04-21', 'location': 'Munich'}, {'logfile': 'log_003', 'vehicle': 'vehicle_01', 'date_captured': '2025-04-22', 'location': 'Frunkfurt'}], 'sample': [{'timestamp': 1650001234567, 'log_token': 'log_001', 'key_camera_token': 'cam_front'}, {'timestamp': 1650001234568, 'log_token': 'log_002', 'key_camera_token': 'cam_front'}, {'timestamp': 1650001234569, 'log_token': 'log_003', 'key_camera_token': 'cam_front'}], 'sample_data': [{'sample_token': 'sample_001', 'ego_pose_token': 'pose_001', 'calibrated_sensor_token': 'calib_001', 'filename': 'image_001.jpg', 'fileformat': 'jpg', 'width': 1920, 'height': 1080, 'timestamp': 1650001234567, 'is_key_frame': True, 'next': 'sample_002', 'prev': None}, {'sample_token': 'sample_002', 'ego_pose_token': 'pose_001', 'calibrated_sensor_token': 'calib_001', 'filename': 'image_0
# ...

# %%
print(database['log'])
# Out:
# [{'logfile': 'log_001', 'vehicle': 'vehicle_01', 'date_captured': '2025-04-20', 'location': 'Berlin'}, {'logfile': 'log_002', 'vehicle': 'vehicle_01', 'date_captured': '2025-04-21', 'location': 'Munich'}, {'logfile': 'log_003', 'vehicle': 'vehicle_01', 'date_captured': '2025-04-22', 'location': 'Frunkfurt'}]

# %%
print(database['log'][1])
# Out:
# {'logfile': 'log_002', 'vehicle': 'vehicle_01', 'date_captured': '2025-04-21', 'location': 'Munich'}

# %%
print(database['log'][1]['location'])
# Out:
# Munich

# %%
print(database['sample'])
# Out:
# [{'timestamp': 1650001234567, 'log_token': 'log_001', 'key_camera_token': 'cam_front'}, {'timestamp': 1650001234568, 'log_token': 'log_002', 'key_camera_token': 'cam_front'}, {'timestamp': 1650001234569, 'log_token': 'log_003', 'key_camera_token': 'cam_front'}]

# %%
print(database['sample_data'][2])
# Out:
# {'sample_token': 'sample_003', 'ego_pose_token': 'pose_001', 'calibrated_sensor_token': 'calib_001', 'filename': 'image_001.jpg', 'fileformat': 'jpg', 'width': 1920, 'height': 1080, 'timestamp': 1650001234567, 'is_key_frame': True, 'next': 'sample_002', 'prev': None}

# %%
print(database['sample_data'][2]['ego_pose_token'])
# Out:
# pose_001

# %%
print(database['ego_pose'])
# Out:
# [{'translation': [10.5, 5.2, 0.3], 'rotation': [0.0, 0.0, 0.0, 1.0], 'timestamp': 1650001234567, 'rotation_rate': [0.01, 0.0, 0.0], 'acceleration': [0.1, 0.0, -9.8], 'speed': 12.3}, {'translation': [11.5, 5.2, 0.3], 'rotation': [0.0, 0.0, 0.0, 1.0], 'timestamp': 1650001234567, 'rotation_rate': [0.01, 0.0, 0.0], 'acceleration': [0.1, 0.0, -9.8], 'speed': 12.4}, {'translation': [15.5, 5.2, 0.3], 'rotation': [0.0, 0.0, 0.0, 1.0], 'timestamp': 1650001234567, 'rotation_rate': [0.01, 0.0, 0.0], 'acceleration': [0.1, 0.0, -9.8], 'speed': 12.6}]

# %%
print(database['ego_pose'][1])
# Out:
# {'translation': [11.5, 5.2, 0.3], 'rotation': [0.0, 0.0, 0.0, 1.0], 'timestamp': 1650001234567, 'rotation_rate': [0.01, 0.0, 0.0], 'acceleration': [0.1, 0.0, -9.8], 'speed': 12.4}

# %%
print(database['ego_pose'][1]['acceleration'], database['ego_pose'][1]['speed'])
# Out:
# [0.1, 0.0, -9.8] 12.4
