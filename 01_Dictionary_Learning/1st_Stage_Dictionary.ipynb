# %%
#Define Dictionary

dic1={"brand":"ford","model":"mustang","year":1964}

# %%
#Call the Dictionary

dic1
# Out:
# {'brand': 'ford', 'model': 'mustang', 'year': 1964}

# %%
# Access the item of Dictionary

dic1["model"]
# Out:
# 'mustang'

# %%
dic1["year"]
# Out:
# 1964

# %%
#store value on a variable
x=dic1.get("model")

# %%
x
# Out:
# 'mustang'

# %%
#Change Value in Dictionary
dic1["year"]=2015

# %%
dic1
# Out:
# {'brand': 'ford', 'model': 'mustang', 'year': 2015}

# %%
#loop in dictionary
#print the category
for x in dic1:
    print(x)
# Out:
# brand
# model
# year

# %%
#print the inside item of category
for x in dic1:
    print(dic1[x])
# Out:
# ford
# mustang
# 2015

# %%
#Search any keyword present on dictionary
if "model" in dic1: 
    print("There is a keyword model")
# Out:
# There is a keyword model

# %%
#know the leangth of dictionary 
len(dic1)
# Out:
# 3

# %%
#add new category and item value on dictionary 
dic1["color"]="red"

# %%
dic1
# Out:
# {'brand': 'ford', 'model': 'mustang', 'year': 2015, 'color': 'red'}

# %%
#to remobe any category 
dic1.pop("model")
# Out:
# 'mustang'

# %%
#now you can't see the model 
dic1
# Out:
# {'brand': 'ford', 'year': 2015, 'color': 'red'}

# %%
#to remove last item
dic1.popitem()
# Out:
# ('color', 'red')

# %%
dic1
# Out:
# {'brand': 'ford', 'year': 2015}

# %%
#to delete dictionary 
del dic1

# %%
#now we can not see this dictionary 
dic1
# Out:
# {'brand': 'ford', 'model': 'mustang', 'year': 1964}

# %%
#again Define Dictionary

dic1={"brand":"ford","model":"mustang","year":1964}

# %%
#to clear dictionary 
dic1.clear()

# %%
#now you the dictionary is empty 
dic1
# Out:
# {}

# %%
#again Define Dictionary

dic1={"brand":"ford","model":"mustang","year":1964}

# %%
#to copy dictionary 
dic2=dic1.copy()

# %%
#now check copy 
dic2
# Out:
# {'brand': 'ford', 'model': 'mustang', 'year': 1964}

# %%
#copy in different method 
dic3=dict(dic1)

# %%
#to check dictionary 3
dic3
# Out:
# {'brand': 'ford', 'model': 'mustang', 'year': 1964}

# %%
#nested dictionary 
mytask={"Task1":{"Name":"learn Dictionary","Deadline":"22nd_April"},"Task2":{"Name":"Schema","Deadline":"22nd_April"}}

# %%
mytask
# Out:
# {'Task1': {'Name': 'learn Dictionary', 'Deadline': '22nd_April'},
#  'Task2': {'Name': 'Schema', 'Deadline': '22nd_April'}}

# %%
#to get a perticular data from a nested dictionary 
mytask["Task2"]
# Out:
# {'Name': 'Schema', 'Deadline': '22nd_April'}

# %%
#to get a perticular data from a nested dictionary 
mytask["Task2"]["Deadline"]
# Out:
# '22nd_April'
