# %%
#list dictionary

products =[ 
    {'itemid': '3001', 'name':'Shirt', 'colour': 'white', 'size': ['small', 'medium', 'large']},
    {'itemid': '3002', 'name':'Glass', 'colour': 'black', 'size': ['small', 'medium', 'large']},
    {'itemid': '3003', 'name':'Watch', 'colour': 'Gold', 'size': ['small', 'medium', 'large']},
    {'itemid': '3004', 'name':'Hoody', 'colour': 'white', 'size': ['small', 'medium', 'large']},
    {'itemid': '3005', 'name':'Hat', 'colour': 'Black', 'size': ['small', 'medium', 'large']},
    {'itemid': '3006', 'name':'Shoes', 'colour': 'white', 'size': ['small', 'medium', 'large']}
]

# %%
products
# Out:
# [{'itemid': '3001',
#   'name': 'Shirt',
#   'colour': 'white',
#   'size': ['small', 'medium', 'large']},
#  {'itemid': '3002',
#   'name': 'Glass',
#   'colour': 'black',
#   'size': ['small', 'medium', 'large']},
#  {'itemid': '3003',
#   'name': 'Watch',
#   'colour': 'Gold',
#   'size': ['small', 'medium', 'large']},
#  {'itemid': '3004',
#   'name': 'Hoody',
#   'colour': 'white',
#   'size': ['small', 'medium', 'large']},
#  {'itemid': '3005',
#   'name': 'Hat',
#   'colour': 'Black',
#   'size': ['small', 'medium', 'large']},
#  {'itemid': '3006',
#   'name': 'Shoes',
#   'colour': 'white',
#   'size': ['small', 'medium', 'large']}]

# %%
print(products[0]['itemid'], products[0]['name'], products[0]['colour'], products[0]['size'][1])
# Out:
# 3001 Shirt white medium

# %%
print(products[5]['itemid'], products[5]['name'], products[5]['size'][1])
# Out:
# 3006 Shoes medium

# %%
d = {}
size = int(input('Enter the size: '))
for i in range(size):
    key = input('Enter the Course Name : ')
    value = input('Enter the Number of Students : ')
    schedule = input('Enter the Class Schedule (Morning/Evening): ')
    d[key] = {'students': value, 'schedule': schedule}

print('The Dictionary is ')
print(d)
# Out:
# Enter the size:  4
# Enter the Course Name :  English
# Enter the Number of Students :  50
# Enter the Class Schedule (Morning/Evening):  Morning
# Enter the Course Name :  German
# Enter the Number of Students :  20
# Enter the Class Schedule (Morning/Evening):  Evening
# Enter the Course Name :  Arabic
# Enter the Number of Students :  80
# Enter the Class Schedule (Morning/Evening):  Morning
# Enter the Course Name :  Bangla
# Enter the Number of Students :  20
# Enter the Class Schedule (Morning/Evening):  Evening
# The Dictionary is
# {'English': {'students': '50', 'schedule': 'Morning'}, 'German': {'students': '20', 'schedule': 'Evening'}, 'Arabic': {'students': '80', 'schedule': 'Morning'}, 'Bangla': {'students': '20', 'schedule': 'Evening'}}
